# %%
import numpy as np 
import pickle 
import pandas as pd 
import h5py
from sklearn.metrics import confusion_matrix
import re
# %matplotlib inline 
import matplotlib.pyplot as plt 
import seaborn as sns
import yaml 
from pathlib import Path
import matplotlib
# matplotlib.rcParams.update({'font.size': 26})
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
import sys
sys.path.append('../')

from importlib import reload
from pathlib import Path

# %%
parent_dir = Path("/mnt/home/igriffith/ceph/projects/cochdnn/fmri_analysis_model_features/")

model_names = [
          "whisper_tiny.en",
          "whisper_medium",
        #   "whisper_large-v3",
          "whisper_large-v3-turbo", # pruned version of large v3
          "kell2018_barlow_equivariant_lmbda_1e-2_lr_2e-1_eq_lmbda_0e-01_audioset_only", # invar. 
          "kell2018_barlow_equivariant_lmbda_1e-2_lr_2e-1_eq_lmbda_5e-01_audioset_only", # equi. 
]

file_name = 'natsound_activations.h5'

# %%
for model in model_names:
    h5_path = parent_dir / model / file_name
    with h5py.File(h5_path.as_posix(), 'r') as h5_f:
        print(model)
        print(h5_f['layer_list'][:])
# Out:
# whisper_tiny.en
# [b'encoder_block_0' b'encoder_block_1' b'encoder_block_2'
#  b'encoder_block_3' b'ln_post']
# whisper_medium
# [b'encoder_block_0' b'encoder_block_1' b'encoder_block_2'
#  b'encoder_block_3' b'encoder_block_4' b'encoder_block_5'
#  b'encoder_block_6' b'encoder_block_7' b'encoder_block_8'
#  b'encoder_block_9' b'encoder_block_10' b'encoder_block_11'
#  b'encoder_block_12' b'encoder_block_13' b'encoder_block_14'
#  b'encoder_block_15' b'encoder_block_16' b'encoder_block_17'
#  b'encoder_block_18' b'encoder_block_19' b'encoder_block_20'
#  b'encoder_block_21' b'encoder_block_22' b'encoder_block_23' b'ln_post']
# whisper_large-v3-turbo
# [b'encoder_block_0' b'encoder_block_1' b'encoder_block_2'
#  b'encoder_block_3' b'encoder_block_4' b'encoder_block_5'
#  b'encoder_block_6' b'encoder_block_7' b'encoder_block_8'
#  b'encoder_block_9' b'encoder_block_10' b'encoder_block_11'
#  b'encoder_block_12' b'encoder_block_13' b'encoder_block_14'
# ...
